# %% [markdown]
# <a href="https://colab.research.google.com/github/roopkanwalvirk97/Weather-data-analysis/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Weather data analysis Project using Python**

# %% [markdown]
# #Import the Library

# %%
import pandas as pd

# %% [markdown]
# # Importing the dataset

# %%
df = pd.read_csv('Weather Data.csv')

# %%
df
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %% [markdown]
# #.head()
# Pandas head() method is used to return top n (5 by default) rows of a data frame or series.

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %% [markdown]
# #.tail()
# The tail() method returns a specified number of last rows.

# %%
df.tail()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
#       Visibility_km  Press_kPa Weather
# 8779            9.7     100.13    Snow
# 8780            9.7     100.03    Snow
# 8781            4.8      99.95    Snow
# 8782            9.7      99.91    Snow
# 8783           11.3      99.89    Snow

# %% [markdown]
# #.shape
# Return a tuple representing the dimensionality of the DataFrame.

# %%
df.shape
# Out:
# (8784, 8)

# %% [markdown]
# #.index
# Return the index information of the DataFrame.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %% [markdown]
# #.columns
# This attribute return the column labels of the given Dataframe.

# %%
df.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %% [markdown]
# #.dtypes
# This returns a Series with the data type of each column.

# %%
df.dtypes
# Out:
# Date/Time            object
# Temp_C              float64
# Dew Point Temp_C    float64
# Rel Hum_%             int64
# Wind Speed_km/h       int64
# Visibility_km       float64
# Press_kPa           float64
# Weather              object
# dtype: object

# %% [markdown]
# #.unique()
# To get unique values from a specific column.

# %%
df['Wind Speed_km/h'].unique()
# Out:
# array([ 4,  7,  6,  9, 15, 13, 20, 22, 19, 24, 30, 35, 39, 32, 33, 26, 44,
#        43, 48, 37, 28, 17, 11,  0, 83, 70, 57, 46, 41, 52, 50, 63, 54,  2])

# %% [markdown]
# #nunique()
#  It is used to get a count of unique values from whole dataframe.

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %% [markdown]
# #.count()
# Count the number of (not NULL) values in each column.

# %%
df.count()
# Out:
# Date/Time           8784
# Temp_C              8784
# Dew Point Temp_C    8784
# Rel Hum_%           8784
# Wind Speed_km/h     8784
# Visibility_km       8784
# Press_kPa           8784
# Weather             8784
# dtype: int64

# %% [markdown]
# #.info()
# This method prints information about the DataFrame.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %% [markdown]
# #.describe()
#  This method returns description of the data in the DataFrame. It is used to view some basic statistical details like percentile, mean, std, etc. of a data frame or a series of numeric values.

# %%
df.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %% [markdown]
# #.value_counts
# Return a Series containing counts of unique values.

# %%
df["Weather"].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %% [markdown]
# # To Find all the unique values in "Visibility_km" in the dataset

# %%
df.nunique()
# Out:
# Date/Time           8784
# Temp_C               533
# Dew Point Temp_C     489
# Rel Hum_%             83
# Wind Speed_km/h       34
# Visibility_km         24
# Press_kPa            518
# Weather               50
# dtype: int64

# %%
df['Visibility_km'].nunique()
# Out:
# 24

# %%
df['Visibility_km'].unique()
# Out:
# array([ 8. ,  4. ,  4.8,  6.4,  1.2, 12.9, 16.1, 25. , 19.3, 24.1,  9.7,
#        11.3, 48.3,  3.2,  2.8,  2.4,  2. ,  0.8,  0.6,  1. ,  1.6,  3.6,
#         0.2,  0.4])

# %% [markdown]
# # To find the number of times when the weather is "Mostly Cloudy"

# %%
df.Weather.value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df.Weather == "Mostly Cloudy"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 16      1/1/2012 16:00     2.6              -0.2         82               13
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# 28       1/2/2012 4:00     2.9              -2.3         69               32
# 29       1/2/2012 5:00     2.6              -2.3         70               32
# ...                ...     ...               ...        ...              ...
# 8743   12/30/2012 7:00    -9.9             -13.2         77               19
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8763   12/31/2012 3:00   -11.8             -14.4         81                6
#
# ...

# %%
df.groupby('Weather').get_group('Mostly Cloudy')
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 16      1/1/2012 16:00     2.6              -0.2         82               13
# 26       1/2/2012 2:00     3.9              -0.9         71               32
# 27       1/2/2012 3:00     3.7              -1.5         69               33
# 28       1/2/2012 4:00     2.9              -2.3         69               32
# 29       1/2/2012 5:00     2.6              -2.3         70               32
# ...                ...     ...               ...        ...              ...
# 8743   12/30/2012 7:00    -9.9             -13.2         77               19
# 8748  12/30/2012 12:00   -12.2             -15.7         75               26
# 8749  12/30/2012 13:00   -12.4             -16.2         73               37
# 8759  12/30/2012 23:00   -12.1             -15.1         78               28
# 8763   12/31/2012 3:00   -11.8             -14.4         81                6
#
# ...

# %% [markdown]
# # To find the number of times when the "relRel Hum" was exactly 85%

# %%
df.head()
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
df[df['Rel Hum_%'] == 85]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 7        1/1/2012 7:00    -1.4              -3.6         85                7
# 8        1/1/2012 8:00    -1.4              -3.6         85                9
# 15      1/1/2012 15:00     1.8              -0.4         85               22
# 21      1/1/2012 21:00     4.0               1.7         85               20
# 127      1/6/2012 7:00   -14.4             -16.3         85               22
# ...                ...     ...               ...        ...              ...
# 8733  12/29/2012 21:00    -9.8             -11.8         85               24
# 8735  12/29/2012 23:00   -10.0             -12.0         85               20
# 8766   12/31/2012 6:00    -9.7             -11.7         85                4
# 8767   12/31/2012 7:00    -9.3             -11.3         85                0
# 8777  12/31/2012 17:00    -1.1              -3.3         85               19
#
#       Visibility_km  Press_kPa       Weather
# ...

# %% [markdown]
# # To find the null values in the data

# %%
df.isnull().sum()
# Out:
# Date/Time           0
# Temp_C              0
# Dew Point Temp_C    0
# Rel Hum_%           0
# Wind Speed_km/h     0
# Visibility_km       0
# Press_kPa           0
# Weather             0
# dtype: int64

# %% [markdown]
# # To find mean Wind Speed_km/h

# %%
df['Wind Speed_km/h'].mean()
# Out:
# 14.94546903460838

# %% [markdown]
# #To find Standard Deviation of "Visibility_km" in the data

# %%
df.Visibility_km.std()
# Out:
# 12.622688245171492

# %% [markdown]
# #To find the variance of "Press_kPa" in the data

# %%
df.Press_kPa.var()
# Out:
# 0.7123440111838423

# %% [markdown]
# #To find all the instances when "Snow Showers" were recorded

# %%
df['Weather'].value_counts()
# Out:
# Mainly Clear                               2106
# Mostly Cloudy                              2069
# Cloudy                                     1728
# Clear                                      1326
# Snow                                        390
# Rain                                        306
# Rain Showers                                188
# Fog                                         150
# Rain,Fog                                    116
# Drizzle,Fog                                  80
# Snow Showers                                 60
# Drizzle                                      41
# Snow,Fog                                     37
# Snow,Blowing Snow                            19
# Rain,Snow                                    18
# Thunderstorms,Rain Showers                   16
# Haze                                         16
# Drizzle,Snow,Fog                             15
# Freezing Rain                                14
# Freezing Drizzle,Snow                        11
# ...

# %%
df[df['Weather'] == "Snow Showers"]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41      1/2/2012 17:00    -2.1              -9.5         57               22
# 44      1/2/2012 20:00    -5.6             -13.4         54               24
# 45      1/2/2012 21:00    -5.8             -12.8         58               26
# 47      1/2/2012 23:00    -7.4             -14.1         59               17
# 48       1/3/2012 0:00    -9.0             -16.0         57               28
# 50       1/3/2012 2:00   -10.5             -15.8         65               22
# 51       1/3/2012 3:00   -11.3             -18.7         54               33
# 53       1/3/2012 5:00   -12.9             -19.1         60               22
# 54       1/3/2012 6:00   -13.3             -19.3         61               19
# 271     1/12/2012 7:00    -7.3             -12.7         65               28
# 569    1/24/2012 17:00     1.6              -2.8         73               26
# ...

# %% [markdown]
# #To find all the instances when "Wind Speed_km/h" is above 30 and "Visibility_km" is 24.1

# %%
df[(df['Wind Speed_km/h'] > 30) & (df['Visibility_km'] == 24.1)]
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 32       1/2/2012 8:00     1.9              -3.3         68               39
# 33       1/2/2012 9:00     1.8              -3.7         67               44
# 34      1/2/2012 10:00     1.5              -4.1         66               43
# 36      1/2/2012 12:00     1.7              -6.2         56               48
# 37      1/2/2012 13:00     1.1              -6.5         57               37
# ...                ...     ...               ...        ...              ...
# 8073    12/2/2012 9:00     5.1               2.6         84               32
# 8150   12/5/2012 14:00     0.8              -6.7         57               35
# 8410  12/16/2012 10:00    -7.7             -13.8         62               32
# 8411  12/16/2012 11:00    -8.2             -13.9         63               35
# 8747  12/30/2012 11:00   -11.9             -15.4         75               32
#
# ...
